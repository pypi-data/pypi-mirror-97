# %%
import os
import shutil
from seeq import spy

# %%
# Log into Seeq Server if you're not using Seeq Data Lab:
spy.login(url='http://localhost:34216', credentials_file='../credentials.key', force=False)
# Out:
# <div style="background-color: #EEFFEE;text-align: left;">Logged in to <strong>http://localhost:34216/api</strong> successfully as <strong>agent_api_key</strong>.<br>Seeq Server Version: <strong>R22.0.45.02</strong><br>Seeq Python Module Version: <strong>0.45.2.153</strong></div>

# %% [markdown]
# # spy.workbooks
#
# The `spy.workbooks` module provides functions for importing and exporting _workbooks_. A workbook is either a _Workbench Analysis_ (colored green in the Seeq user interface) or an _Organizer Topic_ (colored blue).
#
# This functionality is helpful to:
#
# - Move content between two Seeq servers
# - Manage content by exporting and committing to a version control system like Git
#
# The process typically starts by searching for some content that you have created in Seeq and exporting it. However, since this documentation needs some pre-built content to illustrate how it works, there is a pre-built-and-exported set of workbooks alongside this documentation notebook. So we'll go in a non-typical order of operations in this example.

# %% [markdown]
# ## The Export Format
#
# When content is exported from Seeq, each workbook is encapsulated in its own folder, including all its worksheets, calculated item definitions and all dependencies, journal/document images and anything else that is necessary to import that data into another server. Content is written to disk as either JSON, HTML or image files as appropriate. References to datasource items are also catalogued during export and default _datasource maps_ are created that facilitate identification of equivalent signals/conditions/scalars on the destination system so that the imported content gets "hooked up" to the right data.

# %% [markdown]
# ## Main Actions
#
# There are five main operations you can perform on workbooks:
#
# - **search** for workbooks whose content you want to *pull*
# - **pull** those workbooks into `Workbook` in-memory Python objects
# - **save** the `Workbook` Python objects to disk in the export format described above
# - **load** `Workbook` Python objects from disk into memory
# - **push** in-memory `Workbook` Python objects into a Seeq Server
#
# As mentioned, we're going to go out-of-order for illustration purposes: _load_, _push_, _search_, _pull_, _save_.

# %% [markdown]
# ### Importing
#
# This set of documentation comes with an _Example Export_ folder that contains an Analysis and a Topic for illustration purposes. First we **load** it into memory:

# %%
workbooks = spy.workbooks.load('Example Export.zip')
workbooks
# Out:
# <div style="background-color: #EEFFEE;text-align: left;">Success</div>
# [Workbook "Example Analysis" (D833DC83-9A38-48DE-BF45-EB787E9E8375),
#  Workbook "Example Topic" (811B1488-297A-4FD2-AE7C-A1FE0E3B3641)]

# %% [markdown]
# Now that the workbook definitions are in memory, we can push them into Seeq.

# %%
spy.workbooks.push(workbooks, path='My Import', errors='raise')
# Out:
# <div style="background-color: #EEFFEE;text-align: left;">Push successful</div><table><tr><td style="background-color: #EEFFEE;"></td><td style="background-color: #EEFFEE;">ID</td><td style="background-color: #EEFFEE;">Name</td><td style="background-color: #EEFFEE;">Type</td><td style="background-color: #EEFFEE;">Workbook Type</td><td style="background-color: #EEFFEE;">Count</td><td style="background-color: #EEFFEE;">Time</td><td style="background-color: #EEFFEE;">Result</td><td style="background-color: #EEFFEE;">Pushed Workbook ID</td><td style="background-color: #EEFFEE;">URL</td></tr><tr style="background-color: #EEFFEE;"><td>0</td><td>D833DC83-9A38-48DE-BF45-EB787E9E8375</td><td>Example Analysis</td><td>Workbook</td><td>Analysis</td><td>51</td><td>00:00:01.36</td><td>Success</td><td>B70DAB96-988C-452E-9F91-3977802EE2D4</td><td><a target="_blank" href="http://localhost:34216/EC566060-7D5D-421A-870C-25A0E4F437D5/workbook/B70DAB96-988C-452E-9F91-3977802EE2D4/worksheet/AE97E884-A9CC-494D-B73C-155AC4C55CC3">link</a></td></tr><tr style="background-color: #EEFFEE;"><td>1</td><td>811B1488-297A-4FD2-AE7C-A1FE0E3B3641</td><td>Example Topic</td><td>Workbook</td><td>Topic</td><td>6</td><td>00:00:00.15</td><td>Success</td><td>7EF60B3D-1836-4728-8A9E-6CFB9000B609</td><td><a target="_blank" href="http://localhost:34216/EC566060-7D5D-421A-870C-25A0E4F437D5/workbook/7EF60B3D-1836-4728-8A9E-6CFB9000B609/worksheet/E3B5F6ED-FB69-4594-BE09-69C4DEF5C064">link</a></td></tr></table>
#                                      ID              Name      Type  \
# 0  D833DC83-9A38-48DE-BF45-EB787E9E8375  Example Analysis  Workbook
# 1  811B1488-297A-4FD2-AE7C-A1FE0E3B3641     Example Topic  Workbook
#
#   Workbook Type Count            Time   Result  \
# 0      Analysis    51  0:00:01.360896  Success
# 1         Topic     6  0:00:00.151590  Success
#
#                      Pushed Workbook ID  \
# 0  B70DAB96-988C-452E-9F91-3977802EE2D4
# 1  7EF60B3D-1836-4728-8A9E-6CFB9000B609
#
#                                                  URL
# 0  http://localhost:34216/EC566060-7D5D-421A-870C...
# 1  http://localhost:34216/EC566060-7D5D-421A-870C...

# %% [markdown]
# The workbooks have been imported into Seeq in a _My Import_ folder with you as the owner. Refresh Seeq Workbench in your browser and take a look.

# %% [markdown]
# ### Exporting
#
# In Seeq Workbench, try changing the name of the _Example Analysis_ workbook to something like _My First Analysis Export_ so that you can tell that your changes get exported.
#
# Now we will **search** for the workbooks we want to export. The syntax for a workbook search query is very similar to an item metadata search via `spy.search()`:

# %%
workbooks_df = spy.workbooks.search({
    'Path': 'My Import'
})

workbooks_df
# Out:
# <div style="background-color: #EEFFEE;text-align: left;">Query successful.</div><table><tr><td style="background-color: #EEFFEE;"></td><td style="background-color: #EEFFEE;">Count</td><td style="background-color: #EEFFEE;">Time</td></tr><tr style="background-color: #EEFFEE;"><td>Results</td><td>2</td><td>00:00:00.09</td></tr></table>
#    Archived                           Created At  \
# 0       0.0  2020-06-25 19:44:20.763774700+00:00
# 1       0.0  2020-06-25 19:44:21.907146400+00:00
#
#                                      ID              Name  \
# 0  B70DAB96-988C-452E-9F91-3977802EE2D4  Example Analysis
# 1  7EF60B3D-1836-4728-8A9E-6CFB9000B609     Example Topic
#
#                                Owner ID     Owner Name Owner Username  \
# 0  45831CA7-46D9-4D1E-8CBB-4AAD8A7C5864  Agent API Key  agent_api_key
# 1  45831CA7-46D9-4D1E-8CBB-4AAD8A7C5864  Agent API Key  agent_api_key
#
#         Path  Pinned                      Search Folder ID      Type  \
# 0  My Import     0.0  EC566060-7D5D-421A-870C-25A0E4F437D5  Workbook
# 1  My Import     0.0  EC566060-7D5D-421A-870C-25A0E4F437D5  Workbook
#
#                             Updated At Workbook Type
# 0  2020-06-25 19:47:28.104959300+00:00      Analysis
# 1  2020-06-25 19:47:28.351882200+00:00         Topic

# %% [markdown]
# As you can see, the `spy.workbooks.search()` command returns a metadata DataFrame with the properties of the workbooks. We can now use that to **pull**:

# %%
workbooks = spy.workbooks.pull(workbooks_df)
workbooks
# Out:
# <div style="background-color: #EEFFEE;text-align: left;">Pull successful</div><table><tr><td style="background-color: #EEFFEE;"></td><td style="background-color: #EEFFEE;">ID</td><td style="background-color: #EEFFEE;">Name</td><td style="background-color: #EEFFEE;">Workbook Type</td><td style="background-color: #EEFFEE;">Count</td><td style="background-color: #EEFFEE;">Time</td><td style="background-color: #EEFFEE;">Result</td></tr><tr style="background-color: #EEFFEE;"><td>0</td><td>B70DAB96-988C-452E-9F91-3977802EE2D4</td><td>Example Analysis</td><td>Analysis</td><td>46</td><td>00:00:01.15</td><td>Success</td></tr><tr style="background-color: #EEFFEE;"><td>1</td><td>7EF60B3D-1836-4728-8A9E-6CFB9000B609</td><td>Example Topic</td><td>Topic</td><td>6</td><td>00:00:00.25</td><td>Success</td></tr></table>
# [Workbook "Example Analysis" (B70DAB96-988C-452E-9F91-3977802EE2D4),
#  Workbook "Example Topic" (7EF60B3D-1836-4728-8A9E-6CFB9000B609)]

# %% [markdown]
# These are the same type of in-memory Python objects that we had when we executed `spy.workbooks.load()`. Now we can **save** them to disk:

# %%
if os.path.exists('../My First Export'):
    shutil.rmtree('../My First Export')
    
spy.workbooks.save(workbooks, '../My First Export')
# Out:
# <div style="background-color: #EEFFEE;text-align: left;">Success</div>

# %% [markdown]
# In the parent folder of this documentation notebook, you'll find a new _My First Export_ folder that contains similar files to the _Example Export_ folder that's part of the documentation.

# %% [markdown]
# ## Inspecting Worksheets
#
# With the in-memory Python objects that result from `spy.workbooks.pull()` or `spy.workbooks.load()`, you can inspect the worksheets to see what is displayed on them. For example, let's look at what's in the Details Pane of the second worksheet of _Example Analysis_:

# %%
worksheet_items = workbooks[0].worksheets[1].display_items
worksheet_items
# Out:
#   Axis Align Axis Auto Scale Axis Group    Axis Max    Axis Min Axis Show  \
# 0       Left            True          A  120.433655   66.778460      True
# 1       Left            True          A  120.433655   66.778460      True
# 2       Left            True          C   38.162385    0.002923      True
# 3       Left            True          D   96.598636 -100.000000      True
# 4        NaN             NaN        NaN         NaN         NaN       NaN
# 5       Left            True          A  120.433655   66.778460      True
#
#      Color                                    ID  Lane Line Style  Line Width  \
# 0  #068C45  3099FBFE-08D6-496F-80E5-A0F3460836B9   2.0      Solid         1.0
# 1  #9D248F  29FD98E0-8618-4AAD-AA79-5B54DCC8CED6   2.0      Solid         2.5
# 2  #CE561B  4B7DCF3A-8368-431C-8BD7-B2F4B34545CE   1.0      Solid         1.0
# 3  #00A2DD  4B2F16D8-364C-4D22-ADB2-AA6DCD934366   3.0      Solid         1.0
# 4  #4055A3  95A8C194-B94C-4397-9AE4-52E1739825AD   NaN        NaN         NaN
# 5  #E1498E  959B57C9-00AB-41E2-8386-AF8F4BA9F427   2.0       Dash         1.0
#
#                       Name Samples Display       Type
# 0       Area A_Temperature            Line     Signal
# 1       Smooth Temperature            Line     Signal
# 2  Area A_Compressor Power            Line     Signal
# 3       Area C_Temperature            Line     Signal
# 4               High Power             NaN  Condition
# 5        Temperature Limit             NaN     Scalar

# %% [markdown]
# Now you can call `spy.pull()` to pull data for the items in the worksheet.

# %%
spy.pull(worksheet_items, start='2019-01-01T00:00:00', end='2019-01-02T00:00:00')
# Out:
# <div style="background-color: #EEFFEE;text-align: left;">Pull successful from <strong>2019-01-01 00:00:00-08:00</strong> to <strong>2019-01-02 00:00:00-08:00</strong></div><table><tr><td style="background-color: #EEFFEE;"></td><td style="background-color: #EEFFEE;">ID</td><td style="background-color: #EEFFEE;">Name</td><td style="background-color: #EEFFEE;">Count</td><td style="background-color: #EEFFEE;">Time</td><td style="background-color: #EEFFEE;">Result</td></tr><tr style="background-color: #EEFFEE;"><td>0</td><td>3099FBFE-08D6-496F-80E5-A0F3460836B9</td><td>Area A_Temperature</td><td>97</td><td>00:00:00.02</td><td>Success</td></tr><tr style="background-color: #EEFFEE;"><td>1</td><td>29FD98E0-8618-4AAD-AA79-5B54DCC8CED6</td><td>Smooth Temperature</td><td>97</td><td>00:00:00.02</td><td>Success</td></tr><tr style="background-color: #EEFFEE;"><td>2</td><td>4B7DCF3A-8368-431C-8BD7-B2F4B34545CE</td><td>Area A_Compressor Power</td><td>97</td><td>00:00:00.02</td><td>Success</td></tr><tr style="background-color: #EEFFEE;"><td>3</td><td>4B2F16D8-364C-4D22-ADB2-AA6DCD934366</td><td>Area C_Temperature</td><td>97</td><td>00:00:00.02</td><td>Success</td></tr><tr style="background-color: #EEFFEE;"><td>4</td><td>95A8C194-B94C-4397-9AE4-52E1739825AD</td><td>High Power</td><td>1</td><td>00:00:00.01</td><td>Success</td></tr><tr style="background-color: #EEFFEE;"><td>5</td><td>959B57C9-00AB-41E2-8386-AF8F4BA9F427</td><td>Temperature Limit</td><td>1</td><td>00:00:00.00</td><td>Success</td></tr></table>
#                            Area A_Temperature  Smooth Temperature  \
# 2019-01-01 00:00:00-08:00           87.110200           86.931767
# 2019-01-01 00:15:00-08:00           86.751221           86.647913
# 2019-01-01 00:30:00-08:00           86.364014           86.396409
# 2019-01-01 00:45:00-08:00           86.101156           86.187602
# 2019-01-01 01:00:00-08:00           86.023508           86.010431
# 2019-01-01 01:15:00-08:00           85.838905           85.814832
# 2019-01-01 01:30:00-08:00           85.619200           85.533257
# 2019-01-01 01:45:00-08:00           85.224636           85.122066
# 2019-01-01 02:00:00-08:00           84.459696           84.595471
# 2019-01-01 02:15:00-08:00           83.851354           84.018629
# 2019-01-01 02:30:00-08:00           83.466839           83.477889
# 2019-01-01 02:45:00-08:00           82.995125           83.042507
# 2019-01-01 03:00:00-08:00           82.792480           82.737517
# 2019-01-01 03:15:00-08:00           82.646031           82.539004
# 2019-01-01 03:30:00-08:00           82.360000           82.375865
# 2019-01-01 03:45:00-08:00           82.161312           82.151181
# 2019-01-01 04:00:00-08:00           81.457696           81.779776
# 2019-01-01 04:15:00-08:00           81.347632           81.232514
# 2019-01-01 04:30:00-08:00           80.920974           80.572758
# 2019-01-01 04:45:00-08:00           80.075446           79.937164
# 2019-01-01 05:00:00-08:00           79.116252           79.468232
# 2019-01-01 05:15:00-08:00           78.762000           79.231962
# 2019-01-01 05:30:00-08:00           79.505770           79.169703
# 2019-01-01 02:15:00-08:00         0.0         120.433655
# 2019-01-01 02:30:00-08:00         0.0         120.433655
# 2019-01-01 02:45:00-08:00         0.0         120.433655
# 2019-01-01 03:00:00-08:00         0.0         120.433655
# 2019-01-01 03:15:00-08:00         0.0         120.433655
# 2019-01-01 03:30:00-08:00         0.0         120.433655
# 2019-01-01 03:45:00-08:00         0.0         120.433655
# 2019-01-01 04:00:00-08:00         0.0         120.433655
# 2019-01-01 04:15:00-08:00         0.0         120.433655
# 2019-01-01 04:30:00-08:00         0.0         120.433655
# 2019-01-01 04:45:00-08:00         0.0         120.433655
# 2019-01-01 05:00:00-08:00         0.0         120.433655
# 2019-01-01 05:15:00-08:00         0.0         120.433655
# 2019-01-01 05:30:00-08:00         0.0         120.433655
# 2019-01-01 05:45:00-08:00         0.0         120.433655
# 2019-01-01 06:00:00-08:00         0.0         120.433655
# 2019-01-01 06:15:00-08:00         0.0         120.433655
# 2019-01-01 06:30:00-08:00         0.0         120.433655
# 2019-01-01 06:45:00-08:00         0.0         120.433655
# 2019-01-01 07:00:00-08:00         0.0         120.433655
# 2019-01-01 07:15:00-08:00         0.0         120.433655
# ...                               ...                ...
# 2019-01-01 16:45:00-08:00         1.0         120.433655
# 2019-01-01 17:00:00-08:00         1.0         120.433655
# 2019-01-01 17:15:00-08:00         1.0         120.433655
# 2019-01-01 17:30:00-08:00         1.0         120.433655
# 2019-01-01 17:45:00-08:00         1.0         120.433655
# 2019-01-01 18:00:00-08:00         1.0         120.433655
# 2019-01-01 18:15:00-08:00         1.0         120.433655
# 2019-01-01 18:30:00-08:00         1.0         120.433655
# 2019-01-01 18:45:00-08:00         1.0         120.433655
# 2019-01-01 19:00:00-08:00         1.0         120.433655
# 2019-01-01 19:15:00-08:00         1.0         120.433655
# 2019-01-01 19:30:00-08:00         1.0         120.433655
# 2019-01-01 19:45:00-08:00         1.0         120.433655
# 2019-01-01 20:00:00-08:00         1.0         120.433655
# 2019-01-01 20:15:00-08:00         1.0         120.433655
# 2019-01-01 20:30:00-08:00         1.0         120.433655
# 2019-01-01 20:45:00-08:00         1.0         120.433655
# 2019-01-01 21:00:00-08:00         0.0         120.433655
# 2019-01-01 21:15:00-08:00         0.0         120.433655
# 2019-01-01 21:30:00-08:00         0.0         120.433655
# 2019-01-01 21:45:00-08:00         0.0         120.433655
# 2019-01-01 22:00:00-08:00         0.0         120.433655
# 2019-01-01 22:15:00-08:00         0.0         120.433655
# 2019-01-01 22:30:00-08:00         0.0         120.433655
# 2019-01-01 22:45:00-08:00         0.0         120.433655
# 2019-01-01 23:00:00-08:00         0.0         120.433655
# 2019-01-01 23:15:00-08:00         0.0         120.433655
# 2019-01-01 23:30:00-08:00         0.0         120.433655
# 2019-01-01 23:45:00-08:00         0.0         120.433655
# 2019-01-02 00:00:00-08:00         0.0         120.433655
#
# [97 rows x 6 columns]

# %% [markdown]
# Note that if you just wanted the full metadata for the items, you could execute `spy.search(worksheet_items[['ID']])`.

# %% [markdown]
# ## Re-importing and Labels
#
# If you **push** a set of workbooks more than once, then by default you will simply overwrite the existing workbooks with the saved content. This can be useful when you are "backing up" content to disk, perhaps for the purposes of version control.
#
# You can choose to **push** and supply a _label_, which will create a separate copy of all of the imported items instead of modifying the existing ones. This is useful when you want to import something that you are iterating on prior to affecting the "published" version. For example, let's push our workbooks with the label of `In Development`:

# %%
spy.workbooks.push(workbooks, path='My Development Folder', label='In Development')
# Out:
# <div style="background-color: #EEFFEE;text-align: left;">Push successful</div><table><tr><td style="background-color: #EEFFEE;"></td><td style="background-color: #EEFFEE;">ID</td><td style="background-color: #EEFFEE;">Name</td><td style="background-color: #EEFFEE;">Type</td><td style="background-color: #EEFFEE;">Workbook Type</td><td style="background-color: #EEFFEE;">Count</td><td style="background-color: #EEFFEE;">Time</td><td style="background-color: #EEFFEE;">Result</td><td style="background-color: #EEFFEE;">Pushed Workbook ID</td><td style="background-color: #EEFFEE;">URL</td></tr><tr style="background-color: #EEFFEE;"><td>0</td><td>B70DAB96-988C-452E-9F91-3977802EE2D4</td><td>Example Analysis</td><td>Workbook</td><td>Analysis</td><td>51</td><td>00:00:01.23</td><td>Success</td><td>0723C538-0E74-471E-B130-5A9699809038</td><td><a target="_blank" href="http://localhost:34216/004D9716-3C7A-4E7D-9CC4-A814D3C5E919/workbook/0723C538-0E74-471E-B130-5A9699809038/worksheet/A35A8F0F-E34E-4C12-A104-F5E71C98C557">link</a></td></tr><tr style="background-color: #EEFFEE;"><td>1</td><td>7EF60B3D-1836-4728-8A9E-6CFB9000B609</td><td>Example Topic</td><td>Workbook</td><td>Topic</td><td>6</td><td>00:00:00.15</td><td>Success</td><td>E767AD4C-0BF7-4EC6-87EE-040F44A7AE61</td><td><a target="_blank" href="http://localhost:34216/004D9716-3C7A-4E7D-9CC4-A814D3C5E919/workbook/E767AD4C-0BF7-4EC6-87EE-040F44A7AE61/worksheet/A9B6DB26-0E34-4D28-B28C-468254FA89A1">link</a></td></tr></table>
#                                      ID              Name      Type  \
# 0  B70DAB96-988C-452E-9F91-3977802EE2D4  Example Analysis  Workbook
# 1  7EF60B3D-1836-4728-8A9E-6CFB9000B609     Example Topic  Workbook
#
#   Workbook Type Count            Time   Result  \
# 0      Analysis    51  0:00:01.230709  Success
# 1         Topic     6  0:00:00.151597  Success
#
#                      Pushed Workbook ID  \
# 0  0723C538-0E74-471E-B130-5A9699809038
# 1  E767AD4C-0BF7-4EC6-87EE-040F44A7AE61
#
#                                                  URL
# 0  http://localhost:34216/004D9716-3C7A-4E7D-9CC4...
# 1  http://localhost:34216/004D9716-3C7A-4E7D-9CC4...

# %% [markdown]
# If you refresh Seeq Workbench, you'll notice that there is now a _My Development Folder_ and a separate copy of the Topic and Analysis that is independent of the original -- including all calculated items.
#
# Pushing with the same value for the `label` argument will overwrite the content for that label. Change the label again if you want yet another separate copy.

# %% [markdown]
# ## Importing to a Different Seeq Server
#
# You may wish to copy content to a new/different Seeq Server by exporting and then importing. For example, you might have a _development_ server where you iterate on content and a _production_ server that you publish to when finished.
#
# In order to accomplish this, you'll do one of two actions:
#
# - If you're using the SPy module within Seeq Data Lab, you'll copy the exported folder to the other version of Seeq Data Lab and then push it from there.
# - If you're using the SPy module with your own Python set up, you'll log in to the other server and push it.
