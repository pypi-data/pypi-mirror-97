# %%
from seeq import spy
import pandas as pd

# %%
# Log into Seeq Server if you're not using Seeq Data Lab:
spy.login(url='http://localhost:34216', credentials_file='../credentials.key', force=False)
# Out:
# <div style="background-color: #EEFFEE;text-align: left;">Logged in to <strong>http://localhost:34216/api</strong> successfully as <strong>agent_api_key</strong>.<br>Seeq Server Version: <strong>R21.0.44.04</strong><br>Seeq Python Module Version: <strong>0.44.4.136</strong></div>

# %% [markdown]
# # spy.push
#
# Uploads signals, conditions, scalars, and assets to the Seeq Server.
#
# There are two main types of information processed by Seeq: _Data_ and _metadata_:
#
# - **Data** is the time series and time interval information that is either collected or derived from sensor data. It consists of timestamps and values (samples), or time intervals and properties (capsules). This data can be plotted on a trend or used to train a neural network, for example.
#
# - **Metadata** is the information about the data, that is independent of a particular point in time or time interval. For example, a signal's _name_, _description_ and _unit of measure_ is classified as metadata; or the formula that is used to derive a new signal from one or more source signals; or the asset tree that is used to model similar equipment or industrial processes.
#
# The `spy.push()` command allows you to upload both types of information to Seeq Server. When you push _metadata_, you make entries in Seeq's data index, which allows you or other users to search for and find such entries. If you also push _data_, then samples or capsules or scalars will appear when the user selects those index entries for inclusion on a trend, scatter plot, scorecard or other visualization.

# %% [markdown]
# ```
# spy.push(data=None, metadata=None, item_type=None, workbook='Data Lab >> Data Lab Analysis',
#          worksheet='From Data Lab', datasource=None, archive=False, type_mismatches='raise', errors='catalog')
# ```

# %% [markdown]
# ## Workbook scoping
#
# When you push any type of data, it is only available/discoverable within the workbook specified by the `workbook` argument. This allows you to _sandbox_ your activity by default, and only publish to your colleagues later when your experimentation is largely over.

# %% [markdown]
# ## Pushing signal data
#
# The simplest activity you can do with the `spy.push()` command is to read in a CSV file using Pandas and push it into Seeq. It will be stored in Seeq's internal time series database.

# %%
import csv
csv_file = pd.read_csv('csv_import_example.csv', parse_dates=['TIME(unitless)'], index_col='TIME(unitless)')
csv_file.head()
# Out:
#                            BITDEP(ft)  BLOCKCOMP(ft)  DEP_RTN(ft)  DEPTH(ft)  \
# TIME(unitless)
# 2018-07-25 23:00:01-06:00    4630.217         74.813       4627.0   4630.217
# 2018-07-25 23:00:03-06:00    4630.354         74.735       4627.5   4630.354
# 2018-07-25 23:00:05-06:00    4630.470         74.619       4627.5   4630.470
# 2018-07-25 23:00:07-06:00    4630.588         74.501       4627.5   4630.588
# 2018-07-25 23:00:09-06:00    4630.699         74.390       4627.5   4630.699
#
#                            FLOWIN(USgal/min)  FLOWOUTPC(%)  ROP_AVG(ft/h)  \
# TIME(unitless)
# 2018-07-25 23:00:01-06:00            799.857        40.799        142.698
# 2018-07-25 23:00:03-06:00            799.857        40.576        142.698
# 2018-07-25 23:00:05-06:00            799.857        39.929        142.698
# 2018-07-25 23:00:07-06:00            799.857        40.305        210.705
# 2018-07-25 23:00:09-06:00            799.292        40.245        210.705
#
#                            DIFP(psi)
# TIME(unitless)
# 2018-07-25 23:00:01-06:00    454.214
# 2018-07-25 23:00:03-06:00    481.383
# 2018-07-25 23:00:05-06:00    487.502
# 2018-07-25 23:00:07-06:00    561.480
# 2018-07-25 23:00:09-06:00    610.968

# %% [markdown]
# When you want to push data, it must have an index with a datetime data type. That's why we used the `parse_dates` and `index_col` arguments for `Pandas.read_csv()`.
#
# Now you can just push it into Seeq:

# %%
push_results = spy.push(data=csv_file)
push_results
# Out:
# <div style="background-color: #EEFFEE;text-align: left;">Pushed successfully to datasource <strong>Seeq Data Lab [Datasource ID: Seeq Data Lab]</strong> and scoped to workbook ID <strong>DD7F6F24-283C-4138-9195-F1077E4A3FFE</strong><br>Click the following link to see what you pushed in Seeq:<br><a href="http://localhost:34216/E75C3137-38F2-4E50-B872-CC897D7100F3/workbook/DD7F6F24-283C-4138-9195-F1077E4A3FFE/worksheet/06D22E34-1429-4539-868C-0F33DBC56542" target="_new">http://localhost:34216/E75C3137-38F2-4E50-B872-CC897D7100F3/workbook/DD7F6F24-283C-4138-9195-F1077E4A3FFE/worksheet/06D22E34-1429-4539-868C-0F33DBC56542</a></div><table><tr><td style="background-color: #EEFFEE;"></td><td style="background-color: #EEFFEE;">Count</td><td style="background-color: #EEFFEE;">Result</td><td style="background-color: #EEFFEE;">Time</td></tr><tr style="background-color: #EEFFEE;"><td>BITDEP(ft)</td><td>11485</td><td>Success</td><td>00:00:06.43</td></tr><tr style="background-color: #EEFFEE;"><td>BLOCKCOMP(ft)</td><td>11485</td><td>Success</td><td>00:00:05.09</td></tr><tr style="background-color: #EEFFEE;"><td>DEP_RTN(ft)</td><td>11485</td><td>Success</td><td>00:00:04.73</td></tr><tr style="background-color: #EEFFEE;"><td>DEPTH(ft)</td><td>11485</td><td>Success</td><td>00:00:05.90</td></tr><tr style="background-color: #EEFFEE;"><td>FLOWIN(USgal/min)</td><td>11485</td><td>Success</td><td>00:00:05.25</td></tr><tr style="background-color: #EEFFEE;"><td>FLOWOUTPC(%)</td><td>11485</td><td>Success</td><td>00:00:05.91</td></tr><tr style="background-color: #EEFFEE;"><td>ROP_AVG(ft/h)</td><td>11485</td><td>Success</td><td>00:00:04.95</td></tr><tr style="background-color: #EEFFEE;"><td>DIFP(psi)</td><td>11485</td><td>Success</td><td>00:00:04.33</td></tr></table>
#                    Push Count       Push Time Push Result               Name  \
# BITDEP(ft)            11485.0  0:00:06.429804     Success         BITDEP(ft)
# BLOCKCOMP(ft)         11485.0  0:00:05.086397     Success      BLOCKCOMP(ft)
# DEP_RTN(ft)           11485.0  0:00:04.731346     Success        DEP_RTN(ft)
# DEPTH(ft)             11485.0  0:00:05.899195     Success          DEPTH(ft)
# FLOWIN(USgal/min)     11485.0  0:00:05.250957     Success  FLOWIN(USgal/min)
# FLOWOUTPC(%)          11485.0  0:00:05.906205     Success       FLOWOUTPC(%)
# ROP_AVG(ft/h)         11485.0  0:00:04.949735     Success      ROP_AVG(ft/h)
# DIFP(psi)             11485.0  0:00:04.331416     Success          DIFP(psi)
#
#                                                      ID          Type
# BITDEP(ft)         A2EE83F9-3881-4458-8A65-DCAA7897B636  StoredSignal
# BLOCKCOMP(ft)      56DB9BE5-4A33-4847-BA94-97C8BFB2C5CB  StoredSignal
# DEP_RTN(ft)        0FC7EAAF-C3E7-480F-8DE9-B0C7371BB2DB  StoredSignal
# DEPTH(ft)          1C6250DA-0A1C-46F0-A6C6-0F9D2693DF1A  StoredSignal
# FLOWIN(USgal/min)  013167A3-3ECE-4852-8541-E9E9ED483A90  StoredSignal
# FLOWOUTPC(%)       89A1F851-2965-4909-B2C2-A4263F75BB50  StoredSignal
# ROP_AVG(ft/h)      E7AC16B0-9534-450F-8CD6-DF3ABC530434  StoredSignal
# DIFP(psi)          E64ECBFF-D5E0-4306-BCF2-AB33740C5D45  StoredSignal

# %% [markdown]
# NOTE: Pushing data can be relatively slow. This is an area that Seeq will be optimizing in future versions.
#
# You can push multiple times, and as long as the names are the same and the workbook hasn't changed, you'll just add to the existing signal.

# %% [markdown]
# ## Pushing metadata

# %% [markdown]
# Now let's try pushing just metadata. You can see that the column names from the CSV file contain the unit of measure in parentheses. Let's use Pandas to extract the name and the unit of measure as separate columns.

# %%
better_metadata = push_results.copy()
better_metadata['Original Name'] = better_metadata.index
better_metadata['Name'] = better_metadata['Original Name'].str.extract(r'(.*)\(')
better_metadata['Value Unit Of Measure'] = better_metadata['Original Name'].str.extract(r'.*\((.*)\)')
better_metadata
# Out:
#                    Push Count       Push Time Push Result       Name  \
# BITDEP(ft)            11485.0  0:00:06.429804     Success     BITDEP
# BLOCKCOMP(ft)         11485.0  0:00:05.086397     Success  BLOCKCOMP
# DEP_RTN(ft)           11485.0  0:00:04.731346     Success    DEP_RTN
# DEPTH(ft)             11485.0  0:00:05.899195     Success      DEPTH
# FLOWIN(USgal/min)     11485.0  0:00:05.250957     Success     FLOWIN
# FLOWOUTPC(%)          11485.0  0:00:05.906205     Success  FLOWOUTPC
# ROP_AVG(ft/h)         11485.0  0:00:04.949735     Success    ROP_AVG
# DIFP(psi)             11485.0  0:00:04.331416     Success       DIFP
#
#                                                      ID          Type  \
# BITDEP(ft)         A2EE83F9-3881-4458-8A65-DCAA7897B636  StoredSignal
# BLOCKCOMP(ft)      56DB9BE5-4A33-4847-BA94-97C8BFB2C5CB  StoredSignal
# DEP_RTN(ft)        0FC7EAAF-C3E7-480F-8DE9-B0C7371BB2DB  StoredSignal
# DEPTH(ft)          1C6250DA-0A1C-46F0-A6C6-0F9D2693DF1A  StoredSignal
# FLOWIN(USgal/min)  013167A3-3ECE-4852-8541-E9E9ED483A90  StoredSignal
# FLOWOUTPC(%)       89A1F851-2965-4909-B2C2-A4263F75BB50  StoredSignal
# ROP_AVG(ft/h)      E7AC16B0-9534-450F-8CD6-DF3ABC530434  StoredSignal
# DIFP(psi)          E64ECBFF-D5E0-4306-BCF2-AB33740C5D45  StoredSignal
#
#                        Original Name Value Unit Of Measure
# BITDEP(ft)                BITDEP(ft)                    ft
# BLOCKCOMP(ft)          BLOCKCOMP(ft)                    ft
# DEP_RTN(ft)              DEP_RTN(ft)                    ft
# DEPTH(ft)                  DEPTH(ft)                    ft
# FLOWIN(USgal/min)  FLOWIN(USgal/min)             USgal/min
# FLOWOUTPC(%)            FLOWOUTPC(%)                     %
# ROP_AVG(ft/h)          ROP_AVG(ft/h)                  ft/h
# DIFP(psi)                  DIFP(psi)                   psi

# %%
spy.push(metadata=better_metadata)
# Out:
# <div style="background-color: #EEFFEE;text-align: left;">Pushed successfully to datasource <strong>Seeq Data Lab [Datasource ID: Seeq Data Lab]</strong> and scoped to workbook ID <strong>DD7F6F24-283C-4138-9195-F1077E4A3FFE</strong><br>Click the following link to see what you pushed in Seeq:<br><a href="http://localhost:34216/E75C3137-38F2-4E50-B872-CC897D7100F3/workbook/DD7F6F24-283C-4138-9195-F1077E4A3FFE/worksheet/06D22E34-1429-4539-868C-0F33DBC56542" target="_new">http://localhost:34216/E75C3137-38F2-4E50-B872-CC897D7100F3/workbook/DD7F6F24-283C-4138-9195-F1077E4A3FFE/worksheet/06D22E34-1429-4539-868C-0F33DBC56542</a></div><table><tr><td style="background-color: #EEFFEE;"></td><td style="background-color: #EEFFEE;">Asset</td><td style="background-color: #EEFFEE;">Condition</td><td style="background-color: #EEFFEE;">Overall</td><td style="background-color: #EEFFEE;">Relationship</td><td style="background-color: #EEFFEE;">Scalar</td><td style="background-color: #EEFFEE;">Signal</td><td style="background-color: #EEFFEE;">Threshold Metric</td></tr><tr style="background-color: #EEFFEE;"><td>Items pushed</td><td>0</td><td>0</td><td>8</td><td>0</td><td>0</td><td>8</td><td>0</td></tr></table>
#                    Push Count       Push Time       Name  \
# BITDEP(ft)            11485.0  0:00:06.429804     BITDEP
# BLOCKCOMP(ft)         11485.0  0:00:05.086397  BLOCKCOMP
# DEP_RTN(ft)           11485.0  0:00:04.731346    DEP_RTN
# DEPTH(ft)             11485.0  0:00:05.899195      DEPTH
# FLOWIN(USgal/min)     11485.0  0:00:05.250957     FLOWIN
# FLOWOUTPC(%)          11485.0  0:00:05.906205  FLOWOUTPC
# ROP_AVG(ft/h)         11485.0  0:00:04.949735    ROP_AVG
# DIFP(psi)             11485.0  0:00:04.331416       DIFP
#
#                                                      ID          Type  \
# BITDEP(ft)         A2EE83F9-3881-4458-8A65-DCAA7897B636  StoredSignal
# BLOCKCOMP(ft)      56DB9BE5-4A33-4847-BA94-97C8BFB2C5CB  StoredSignal
# DEP_RTN(ft)        0FC7EAAF-C3E7-480F-8DE9-B0C7371BB2DB  StoredSignal
# DEPTH(ft)          1C6250DA-0A1C-46F0-A6C6-0F9D2693DF1A  StoredSignal
# FLOWIN(USgal/min)  013167A3-3ECE-4852-8541-E9E9ED483A90  StoredSignal
# FLOWOUTPC(%)       89A1F851-2965-4909-B2C2-A4263F75BB50  StoredSignal
# ROP_AVG(ft/h)      E7AC16B0-9534-450F-8CD6-DF3ABC530434  StoredSignal
# DIFP(psi)          E64ECBFF-D5E0-4306-BCF2-AB33740C5D45  StoredSignal
#
#                        Original Name Value Unit Of Measure Push Result
# BITDEP(ft)                BITDEP(ft)                    ft     Success
# BLOCKCOMP(ft)          BLOCKCOMP(ft)                    ft     Success
# DEP_RTN(ft)              DEP_RTN(ft)                    ft     Success
# DEPTH(ft)                  DEPTH(ft)                    ft     Success
# FLOWIN(USgal/min)  FLOWIN(USgal/min)             USgal/min     Success
# FLOWOUTPC(%)            FLOWOUTPC(%)                     %     Success
# ROP_AVG(ft/h)          ROP_AVG(ft/h)                  ft/h     Success
# DIFP(psi)                  DIFP(psi)                   psi     Success

# %% [markdown]
# ## Pushing condition and capsule data

# %% [markdown]
# You can also push capsules, which are time intervals of interest, to Seeq by supplying a DataFrame with `Capsule Start` and `Capsule End` columns. Any additional columns will be added as properties of the capsule.

# %%
capsule_data = pd.DataFrame([{
    'Capsule Start':    pd.to_datetime('2019-01-10T09:00:00.000Z'),
    'Capsule End':      pd.to_datetime('2019-01-10T17:00:00.000Z'),
    'Operator On Duty': 'Mark'
}, {
    'Capsule Start':    pd.to_datetime('2019-01-11T09:00:00.000Z'),
    'Capsule End':      pd.to_datetime('2019-01-11T17:00:00.000Z'),
    'Operator On Duty': 'Hedwig'
}])

capsule_data
# Out:
#                 Capsule End             Capsule Start Operator On Duty
# 0 2019-01-10 17:00:00+00:00 2019-01-10 09:00:00+00:00             Mark
# 1 2019-01-11 17:00:00+00:00 2019-01-11 09:00:00+00:00           Hedwig

# %% [markdown]
# When you push capsule data, you must supply a `metadata` DataFrame that is exactly 1 row and contains, at minimum, the `Name`, `Type` and `Maximum Duration` columns like so:

# %%
spy.push(data=capsule_data,
         metadata=pd.DataFrame([{
             'Name': 'Operator Shifts',
             'Type': 'Condition',
             'Maximum Duration': '2d'
         }]))
# Out:
# <div style="background-color: #EEFFEE;text-align: left;">Pushed successfully to datasource <strong>Seeq Data Lab [Datasource ID: Seeq Data Lab]</strong> and scoped to workbook ID <strong>DD7F6F24-283C-4138-9195-F1077E4A3FFE</strong><br>Click the following link to see what you pushed in Seeq:<br><a href="http://localhost:34216/E75C3137-38F2-4E50-B872-CC897D7100F3/workbook/DD7F6F24-283C-4138-9195-F1077E4A3FFE/worksheet/06D22E34-1429-4539-868C-0F33DBC56542" target="_new">http://localhost:34216/E75C3137-38F2-4E50-B872-CC897D7100F3/workbook/DD7F6F24-283C-4138-9195-F1077E4A3FFE/worksheet/06D22E34-1429-4539-868C-0F33DBC56542</a></div><table><tr><td style="background-color: #EEFFEE;"></td><td style="background-color: #EEFFEE;">ID</td><td style="background-color: #EEFFEE;">Name</td><td style="background-color: #EEFFEE;">Count</td><td style="background-color: #EEFFEE;">Time</td><td style="background-color: #EEFFEE;">Result</td></tr><tr style="background-color: #EEFFEE;"><td>0</td><td>4C0A0639-677F-499D-BCB1-62815A0AB426</td><td>Operator Shifts</td><td>2</td><td>00:00:00.07</td><td>Success</td></tr></table>
#   Maximum Duration             Name             Type Datasource Class  \
# 0               2d  Operator Shifts  StoredCondition    Seeq Data Lab
#
#    Datasource ID                                            Data ID  \
# 0  Seeq Data Lab  [DD7F6F24-283C-4138-9195-F1077E4A3FFE] {Condit...
#
#                                      ID Push Result  Push Count  \
# 0  4C0A0639-677F-499D-BCB1-62815A0AB426     Success           2
#
#         Push Time
# 0  0:00:00.065824
